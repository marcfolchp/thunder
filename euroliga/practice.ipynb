# %%
from euroleague_api.game_stats import GameStats
from euroleague_api.player_stats import PlayerStats
from euroleague_api.play_by_play_data import PlayByPlay

# %%
# En busca de si teniamos la información al respecto de las subsituticiones (y sus tiempos): SÍ.
# El único problema es que solo tenemos este dato desde 2007 (inclusive).

plays = PlayByPlay()

x = plays.get_game_play_by_play_data(season=2024, gamecode=17)

x[(x['PLAYINFO']=='In') | (x['PLAYINFO']=='Out')]
# Out:
#      Season  Gamecode  TYPE  NUMBEROFPLAY CODETEAM PLAYER_ID PLAYTYPE  \
# 38     2024        17     0            81      BAR   P002939       IN
# 39     2024        17     0            82      BAR   P010106      OUT
# 42     2024        17     0            86      BER   P011934      OUT
# 43     2024        17     0            87      BER   P010791       IN
# 44     2024        17     0            88      BER   P011631       IN
# ..      ...       ...   ...           ...      ...       ...      ...
# 497    2024        17     0           578      BAR   P006435       IN
# 513    2024        17     0           596      BER   P011934       IN
# 514    2024        17     0           597      BER   P010791      OUT
# 515    2024        17     0           599      BER   P006919      OUT
# 516    2024        17     0           600      BER   P012721       IN
#
#                     PLAYER          TEAM DORSAL  MINUTE MARKERTIME  POINTS_A  \
# ...
