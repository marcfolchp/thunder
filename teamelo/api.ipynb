# %%
import requests
import pandas as pd

# %%
import requests

url = "https://api.football-data.org/v4/competitions/PD/matches?season=2023"

headers = {
    "X-Auth-Token": "f3f225de51ce40f3b8e8558377c4f7dd"
}

response = requests.get(url, headers=headers)

# %%
data = response.json()

# %%
data
# Out:
# {'filters': {'season': 2023},
#  'resultSet': {'count': 380,
#   'first': '2023-08-11',
#   'last': '2024-05-26',
#   'played': 380},
#  'competition': {'id': 2014,
#   'name': 'Primera Division',
#   'code': 'PD',
#   'type': 'LEAGUE',
#   'emblem': 'https://crests.football-data.org/laliga.png'},
#  'matches': [{'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438482,
#    'utcDate': '2023-08-11T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'awayTeam': {'id': 87,
#     'name': 'Rayo Vallecano de Madrid',
#     'shortName': 'Rayo Vallecano',
#     'tla': 'RAY',
#     'crest': 'https://crests.football-data.org/87.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 80747,
#      'name': 'Javier Alberola Rojas',
#      'type': 'REFEREE',
#      'nationality': None}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438479,
#    'utcDate': '2023-08-11T20:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 559,
#     'name': 'Sevilla FC',
#     'shortName': 'Sevilla FC',
#     'tla': 'SEV',
#     'crest': 'https://crests.football-data.org/559.png'},
#    'awayTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207080,
#      'name': 'José Sánchez Martínez',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438481,
#    'utcDate': '2023-08-12T15:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 92,
#     'name': 'Real Sociedad de Fútbol',
#     'shortName': 'Real Sociedad',
#     'tla': 'RSO',
#     'crest': 'https://crests.football-data.org/92.png'},
#    'awayTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 214213,
#      'name': 'Francisco Hernández Maeso',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438483,
#    'utcDate': '2023-08-12T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 275,
#     'name': 'UD Las Palmas',
#     'shortName': 'Las Palmas',
#     'tla': 'LPA',
#     'crest': 'https://crests.football-data.org/275.png'},
#    'awayTeam': {'id': 89,
#     'name': 'RCD Mallorca',
#     'shortName': 'Mallorca',
#     'tla': 'MAL',
#     'crest': 'https://crests.football-data.org/89.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 56995,
#      'name': 'Víctor García Verdura',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438474,
#    'utcDate': '2023-08-12T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 77,
#     'name': 'Athletic Club',
#     'shortName': 'Athletic',
#     'tla': 'ATH',
#     'crest': 'https://crests.football-data.org/77.png'},
#    'awayTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206211,
#      'name': 'Jesús Gil Manzano',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438476,
#    'utcDate': '2023-08-13T15:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 558,
#     'name': 'RC Celta de Vigo',
#     'shortName': 'Celta',
#     'tla': 'CEL',
#     'crest': 'https://crests.football-data.org/558.png'},
#    'awayTeam': {'id': 79,
#     'name': 'CA Osasuna',
#     'shortName': 'Osasuna',
#     'tla': 'OSA',
#     'crest': 'https://crests.football-data.org/79.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206206,
#      'name': 'Pablo González Fuertes',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438480,
#    'utcDate': '2023-08-13T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'awayTeam': {'id': 90,
#     'name': 'Real Betis Balompié',
#     'shortName': 'Real Betis',
#     'tla': 'BET',
#     'crest': 'https://crests.football-data.org/90.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207048,
#      'name': 'Miguel Ortiz Arias',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438478,
#    'utcDate': '2023-08-13T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 82,
#     'name': 'Getafe CF',
#     'shortName': 'Getafe',
#     'tla': 'GET',
#     'crest': 'https://crests.football-data.org/82.png'},
#    'awayTeam': {'id': 81,
#     'name': 'FC Barcelona',
#     'shortName': 'Barça',
#     'tla': 'FCB',
#     'crest': 'https://crests.football-data.org/81.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207113,
#      'name': 'César Soto Grado',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438477,
#    'utcDate': '2023-08-14T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 264,
#     'name': 'Cádiz CF',
#     'shortName': 'Cádiz CF',
#     'tla': 'CAD',
#     'crest': 'https://crests.football-data.org/264.png'},
#    'awayTeam': {'id': 263,
#     'name': 'Deportivo Alavés',
#     'shortName': 'Alavés',
#     'tla': 'ALA',
#     'crest': 'https://crests.football-data.org/263.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 57930,
#      'name': 'Isidro Díaz de Mera',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438475,
#    'utcDate': '2023-08-14T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 1,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 78,
#     'name': 'Club Atlético de Madrid',
#     'shortName': 'Atleti',
#     'tla': 'ATL',
#     'crest': 'https://crests.football-data.org/78.png'},
#    'awayTeam': {'id': 83,
#     'name': 'Granada CF',
#     'shortName': 'Granada',
#     'tla': 'GRA',
#     'crest': 'https://crests.football-data.org/83.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 3, 'away': 1},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207133,
#      'name': 'Juan Pulido Santana',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438491,
#    'utcDate': '2023-08-18T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 89,
#     'name': 'RCD Mallorca',
#     'shortName': 'Mallorca',
#     'tla': 'MAL',
#     'crest': 'https://crests.football-data.org/89.png'},
#    'awayTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 1},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 80747,
#      'name': 'Javier Alberola Rojas',
#      'type': 'REFEREE',
#      'nationality': None}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438490,
#    'utcDate': '2023-08-18T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'awayTeam': {'id': 275,
#     'name': 'UD Las Palmas',
#     'shortName': 'Las Palmas',
#     'tla': 'LPA',
#     'crest': 'https://crests.football-data.org/275.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215462,
#      'name': 'Javier Iglesias Villanueva',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438492,
#    'utcDate': '2023-08-19T15:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 92,
#     'name': 'Real Sociedad de Fútbol',
#     'shortName': 'Real Sociedad',
#     'tla': 'RSO',
#     'crest': 'https://crests.football-data.org/92.png'},
#    'awayTeam': {'id': 558,
#     'name': 'RC Celta de Vigo',
#     'shortName': 'Celta',
#     'tla': 'CEL',
#     'crest': 'https://crests.football-data.org/558.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207048,
#      'name': 'Miguel Ortiz Arias',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438493,
#    'utcDate': '2023-08-19T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'awayTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 3},
#     'halfTime': {'home': 1, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207080,
#      'name': 'José Sánchez Martínez',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438485,
#    'utcDate': '2023-08-19T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 79,
#     'name': 'CA Osasuna',
#     'shortName': 'Osasuna',
#     'tla': 'OSA',
#     'crest': 'https://crests.football-data.org/79.png'},
#    'awayTeam': {'id': 77,
#     'name': 'Athletic Club',
#     'shortName': 'Athletic',
#     'tla': 'ATH',
#     'crest': 'https://crests.football-data.org/77.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206223,
#      'name': 'José Munuera Montero',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438488,
#    'utcDate': '2023-08-20T17:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'awayTeam': {'id': 82,
#     'name': 'Getafe CF',
#     'shortName': 'Getafe',
#     'tla': 'GET',
#     'crest': 'https://crests.football-data.org/82.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 3, 'away': 0},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215559,
#      'name': 'Jorge Figueroa Vázquez',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438487,
#    'utcDate': '2023-08-20T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 81,
#     'name': 'FC Barcelona',
#     'shortName': 'Barça',
#     'tla': 'FCB',
#     'crest': 'https://crests.football-data.org/81.png'},
#    'awayTeam': {'id': 264,
#     'name': 'Cádiz CF',
#     'shortName': 'Cádiz CF',
#     'tla': 'CAD',
#     'crest': 'https://crests.football-data.org/264.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 2, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215569,
#      'name': 'Alejandro Muñiz Ruiz',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438484,
#    'utcDate': '2023-08-20T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 90,
#     'name': 'Real Betis Balompié',
#     'shortName': 'Real Betis',
#     'tla': 'BET',
#     'crest': 'https://crests.football-data.org/90.png'},
#    'awayTeam': {'id': 78,
#     'name': 'Club Atlético de Madrid',
#     'shortName': 'Atleti',
#     'tla': 'ATL',
#     'crest': 'https://crests.football-data.org/78.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 15628,
#      'name': 'Ricardo de Burgos',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438486,
#    'utcDate': '2023-08-21T17:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 263,
#     'name': 'Deportivo Alavés',
#     'shortName': 'Alavés',
#     'tla': 'ALA',
#     'crest': 'https://crests.football-data.org/263.png'},
#    'awayTeam': {'id': 559,
#     'name': 'Sevilla FC',
#     'shortName': 'Sevilla FC',
#     'tla': 'SEV',
#     'crest': 'https://crests.football-data.org/559.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 4, 'away': 3},
#     'halfTime': {'home': 2, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206215,
#      'name': 'Guillermo Cuadra Fernández',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438489,
#    'utcDate': '2023-08-21T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 2,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 83,
#     'name': 'Granada CF',
#     'shortName': 'Granada',
#     'tla': 'GRA',
#     'crest': 'https://crests.football-data.org/83.png'},
#    'awayTeam': {'id': 87,
#     'name': 'Rayo Vallecano de Madrid',
#     'shortName': 'Rayo Vallecano',
#     'tla': 'RAY',
#     'crest': 'https://crests.football-data.org/87.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206206,
#      'name': 'Pablo González Fuertes',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438503,
#    'utcDate': '2023-08-25T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 275,
#     'name': 'UD Las Palmas',
#     'shortName': 'Las Palmas',
#     'tla': 'LPA',
#     'crest': 'https://crests.football-data.org/275.png'},
#    'awayTeam': {'id': 92,
#     'name': 'Real Sociedad de Fútbol',
#     'shortName': 'Real Sociedad',
#     'tla': 'RSO',
#     'crest': 'https://crests.football-data.org/92.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206215,
#      'name': 'Guillermo Cuadra Fernández',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438495,
#    'utcDate': '2023-08-25T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 558,
#     'name': 'RC Celta de Vigo',
#     'shortName': 'Celta',
#     'tla': 'CEL',
#     'crest': 'https://crests.football-data.org/558.png'},
#    'awayTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 1},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 57930,
#      'name': 'Isidro Díaz de Mera',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438496,
#    'utcDate': '2023-08-26T17:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 264,
#     'name': 'Cádiz CF',
#     'shortName': 'Cádiz CF',
#     'tla': 'CAD',
#     'crest': 'https://crests.football-data.org/264.png'},
#    'awayTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 56995,
#      'name': 'Víctor García Verdura',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438498,
#    'utcDate': '2023-08-26T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 83,
#     'name': 'Granada CF',
#     'shortName': 'Granada',
#     'tla': 'GRA',
#     'crest': 'https://crests.football-data.org/83.png'},
#    'awayTeam': {'id': 89,
#     'name': 'RCD Mallorca',
#     'shortName': 'Mallorca',
#     'tla': 'MAL',
#     'crest': 'https://crests.football-data.org/89.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 3, 'away': 2},
#     'halfTime': {'home': 1, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 214213,
#      'name': 'Francisco Hernández Maeso',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438499,
#    'utcDate': '2023-08-26T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 559,
#     'name': 'Sevilla FC',
#     'shortName': 'Sevilla FC',
#     'tla': 'SEV',
#     'crest': 'https://crests.football-data.org/559.png'},
#    'awayTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 1, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206211,
#      'name': 'Jesús Gil Manzano',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438501,
#    'utcDate': '2023-08-27T15:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'awayTeam': {'id': 81,
#     'name': 'FC Barcelona',
#     'shortName': 'Barça',
#     'tla': 'FCB',
#     'crest': 'https://crests.football-data.org/81.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 3, 'away': 4},
#     'halfTime': {'home': 2, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206208,
#      'name': 'Alejandro Hernández Hernández',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438500,
#    'utcDate': '2023-08-27T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'awayTeam': {'id': 79,
#     'name': 'CA Osasuna',
#     'shortName': 'Osasuna',
#     'tla': 'OSA',
#     'crest': 'https://crests.football-data.org/79.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207133,
#      'name': 'Juan Pulido Santana',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438494,
#    'utcDate': '2023-08-27T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 77,
#     'name': 'Athletic Club',
#     'shortName': 'Athletic',
#     'tla': 'ATH',
#     'crest': 'https://crests.football-data.org/77.png'},
#    'awayTeam': {'id': 90,
#     'name': 'Real Betis Balompié',
#     'shortName': 'Real Betis',
#     'tla': 'BET',
#     'crest': 'https://crests.football-data.org/90.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 4, 'away': 2},
#     'halfTime': {'home': 3, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207113,
#      'name': 'César Soto Grado',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438497,
#    'utcDate': '2023-08-28T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 82,
#     'name': 'Getafe CF',
#     'shortName': 'Getafe',
#     'tla': 'GET',
#     'crest': 'https://crests.football-data.org/82.png'},
#    'awayTeam': {'id': 263,
#     'name': 'Deportivo Alavés',
#     'shortName': 'Alavés',
#     'tla': 'ALA',
#     'crest': 'https://crests.football-data.org/263.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206203,
#      'name': 'Juan Martínez Munuera',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438502,
#    'utcDate': '2023-08-28T19:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 3,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 87,
#     'name': 'Rayo Vallecano de Madrid',
#     'shortName': 'Rayo Vallecano',
#     'tla': 'RAY',
#     'crest': 'https://crests.football-data.org/87.png'},
#    'awayTeam': {'id': 78,
#     'name': 'Club Atlético de Madrid',
#     'shortName': 'Atleti',
#     'tla': 'ATL',
#     'crest': 'https://crests.football-data.org/78.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 7},
#     'halfTime': {'home': 0, 'away': 3}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206223,
#      'name': 'José Munuera Montero',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438508,
#    'utcDate': '2023-09-01T17:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 264,
#     'name': 'Cádiz CF',
#     'shortName': 'Cádiz CF',
#     'tla': 'CAD',
#     'crest': 'https://crests.football-data.org/264.png'},
#    'awayTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 3, 'away': 1},
#     'halfTime': {'home': 2, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207133,
#      'name': 'Juan Pulido Santana',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438513,
#    'utcDate': '2023-09-01T20:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'awayTeam': {'id': 558,
#     'name': 'RC Celta de Vigo',
#     'shortName': 'Celta',
#     'tla': 'CEL',
#     'crest': 'https://crests.football-data.org/558.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 2, 'away': 3},
#     'halfTime': {'home': 0, 'away': 2}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 15628,
#      'name': 'Ricardo de Burgos',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438512,
#    'utcDate': '2023-09-02T12:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 92,
#     'name': 'Real Sociedad de Fútbol',
#     'shortName': 'Real Sociedad',
#     'tla': 'RSO',
#     'crest': 'https://crests.football-data.org/92.png'},
#    'awayTeam': {'id': 83,
#     'name': 'Granada CF',
#     'shortName': 'Granada',
#     'tla': 'GRA',
#     'crest': 'https://crests.football-data.org/83.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 5, 'away': 3},
#     'halfTime': {'home': 2, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215462,
#      'name': 'Javier Iglesias Villanueva',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438511,
#    'utcDate': '2023-09-02T14:15:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'awayTeam': {'id': 82,
#     'name': 'Getafe CF',
#     'shortName': 'Getafe',
#     'tla': 'GET',
#     'crest': 'https://crests.football-data.org/82.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 2, 'away': 1},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207105,
#      'name': 'Mario Melero López',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438507,
#    'utcDate': '2023-09-02T16:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 263,
#     'name': 'Deportivo Alavés',
#     'shortName': 'Alavés',
#     'tla': 'ALA',
#     'crest': 'https://crests.football-data.org/263.png'},
#    'awayTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206206,
#      'name': 'Pablo González Fuertes',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438505,
#    'utcDate': '2023-09-02T19:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 90,
#     'name': 'Real Betis Balompié',
#     'shortName': 'Real Betis',
#     'tla': 'BET',
#     'crest': 'https://crests.football-data.org/90.png'},
#    'awayTeam': {'id': 87,
#     'name': 'Rayo Vallecano de Madrid',
#     'shortName': 'Rayo Vallecano',
#     'tla': 'RAY',
#     'crest': 'https://crests.football-data.org/87.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215569,
#      'name': 'Alejandro Muñiz Ruiz',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438509,
#    'utcDate': '2023-09-03T12:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2023-10-09T15:20:25Z',
#    'homeTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'awayTeam': {'id': 275,
#     'name': 'UD Las Palmas',
#     'shortName': 'Las Palmas',
#     'tla': 'LPA',
#     'crest': 'https://crests.football-data.org/275.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 217698,
#      'name': 'Mateo Busquets Ferrer',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438510,
#    'utcDate': '2023-09-03T14:15:00Z',
#    'status': 'FINISHED',
#    'matchday': 4,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
# ...
#    'lastUpdated': '2024-05-20T00:21:12Z',
#    'homeTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'awayTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 3},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206215,
#      'name': 'Guillermo Cuadra Fernández',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438842,
#    'utcDate': '2024-05-19T17:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 37,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'awayTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 4, 'away': 4},
#     'halfTime': {'home': 1, 'away': 4}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206208,
#      'name': 'Alejandro Hernández Hernández',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438843,
#    'utcDate': '2024-05-19T17:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 37,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-20T00:21:12Z',
#    'homeTeam': {'id': 89,
#     'name': 'RCD Mallorca',
#     'shortName': 'Mallorca',
#     'tla': 'MAL',
#     'crest': 'https://crests.football-data.org/89.png'},
#    'awayTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 2, 'away': 2},
#     'halfTime': {'home': 1, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 15628,
#      'name': 'Ricardo de Burgos',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438847,
#    'utcDate': '2024-05-24T19:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-25T00:21:07Z',
#    'homeTeam': {'id': 298,
#     'name': 'Girona FC',
#     'shortName': 'Girona',
#     'tla': 'GIR',
#     'crest': 'https://crests.football-data.org/298.png'},
#    'awayTeam': {'id': 83,
#     'name': 'Granada CF',
#     'shortName': 'Granada',
#     'tla': 'GRA',
#     'crest': 'https://crests.football-data.org/83.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 7, 'away': 0},
#     'halfTime': {'home': 3, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215569,
#      'name': 'Alejandro Muñiz Ruiz',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438844,
#    'utcDate': '2024-05-25T12:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-26T00:21:07Z',
#    'homeTeam': {'id': 79,
#     'name': 'CA Osasuna',
#     'shortName': 'Osasuna',
#     'tla': 'OSA',
#     'crest': 'https://crests.football-data.org/79.png'},
#    'awayTeam': {'id': 94,
#     'name': 'Villarreal CF',
#     'shortName': 'Villarreal',
#     'tla': 'VIL',
#     'crest': 'https://crests.football-data.org/94.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 1, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207105,
#      'name': 'Mario Melero López',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438851,
#    'utcDate': '2024-05-25T14:15:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-26T00:21:07Z',
#    'homeTeam': {'id': 92,
#     'name': 'Real Sociedad de Fútbol',
#     'shortName': 'Real Sociedad',
#     'tla': 'RSO',
#     'crest': 'https://crests.football-data.org/92.png'},
#    'awayTeam': {'id': 78,
#     'name': 'Club Atlético de Madrid',
#     'shortName': 'Atleti',
#     'tla': 'ATL',
#     'crest': 'https://crests.football-data.org/78.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 2},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207080,
#      'name': 'José Sánchez Martínez',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438849,
#    'utcDate': '2024-05-25T16:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-26T00:21:07Z',
#    'homeTeam': {'id': 87,
#     'name': 'Rayo Vallecano de Madrid',
#     'shortName': 'Rayo Vallecano',
#     'tla': 'RAY',
#     'crest': 'https://crests.football-data.org/87.png'},
#    'awayTeam': {'id': 77,
#     'name': 'Athletic Club',
#     'shortName': 'Athletic',
#     'tla': 'ATH',
#     'crest': 'https://crests.football-data.org/77.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 1},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 206223,
#      'name': 'José Munuera Montero',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438852,
#    'utcDate': '2024-05-25T16:30:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-25T20:20:16Z',
#    'homeTeam': {'id': 267,
#     'name': 'UD Almería',
#     'shortName': 'Almería',
#     'tla': 'ALM',
#     'crest': 'https://crests.football-data.org/267.png'},
#    'awayTeam': {'id': 264,
#     'name': 'Cádiz CF',
#     'shortName': 'Cádiz CF',
#     'tla': 'CAD',
#     'crest': 'https://crests.football-data.org/264.png'},
#    'score': {'winner': 'HOME_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 6, 'away': 1},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 217698,
#      'name': 'Mateo Busquets Ferrer',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438850,
#    'utcDate': '2024-05-25T19:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-06-09T20:20:41Z',
#    'homeTeam': {'id': 86,
#     'name': 'Real Madrid CF',
#     'shortName': 'Real Madrid',
#     'tla': 'RMA',
#     'crest': 'https://crests.football-data.org/86.png'},
#    'awayTeam': {'id': 90,
#     'name': 'Real Betis Balompié',
#     'shortName': 'Real Betis',
#     'tla': 'BET',
#     'crest': 'https://crests.football-data.org/90.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 0, 'away': 0},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 57930,
#      'name': 'Isidro Díaz de Mera',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438846,
#    'utcDate': '2024-05-26T12:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-27T00:21:10Z',
#    'homeTeam': {'id': 82,
#     'name': 'Getafe CF',
#     'shortName': 'Getafe',
#     'tla': 'GET',
#     'crest': 'https://crests.football-data.org/82.png'},
#    'awayTeam': {'id': 89,
#     'name': 'RCD Mallorca',
#     'shortName': 'Mallorca',
#     'tla': 'MAL',
#     'crest': 'https://crests.football-data.org/89.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 56995,
#      'name': 'Víctor García Verdura',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438845,
#    'utcDate': '2024-05-26T14:15:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-28T20:21:14Z',
#    'homeTeam': {'id': 558,
#     'name': 'RC Celta de Vigo',
#     'shortName': 'Celta',
#     'tla': 'CEL',
#     'crest': 'https://crests.football-data.org/558.png'},
#    'awayTeam': {'id': 95,
#     'name': 'Valencia CF',
#     'shortName': 'Valencia',
#     'tla': 'VAL',
#     'crest': 'https://crests.football-data.org/95.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 2, 'away': 2},
#     'halfTime': {'home': 0, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 207048,
#      'name': 'Miguel Ortiz Arias',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438853,
#    'utcDate': '2024-05-26T14:15:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-27T00:21:10Z',
#    'homeTeam': {'id': 275,
#     'name': 'UD Las Palmas',
#     'shortName': 'Las Palmas',
#     'tla': 'LPA',
#     'crest': 'https://crests.football-data.org/275.png'},
#    'awayTeam': {'id': 263,
#     'name': 'Deportivo Alavés',
#     'shortName': 'Alavés',
#     'tla': 'ALA',
#     'crest': 'https://crests.football-data.org/263.png'},
#    'score': {'winner': 'DRAW',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 1},
#     'halfTime': {'home': 0, 'away': 0}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 214213,
#      'name': 'Francisco Hernández Maeso',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]},
#   {'area': {'id': 2224,
#     'name': 'Spain',
#     'code': 'ESP',
#     'flag': 'https://crests.football-data.org/760.svg'},
#    'competition': {'id': 2014,
#     'name': 'Primera Division',
#     'code': 'PD',
#     'type': 'LEAGUE',
#     'emblem': 'https://crests.football-data.org/laliga.png'},
#    'season': {'id': 1577,
#     'startDate': '2023-08-13',
#     'endDate': '2024-05-26',
#     'currentMatchday': 38,
#     'winner': None},
#    'id': 438848,
#    'utcDate': '2024-05-26T19:00:00Z',
#    'status': 'FINISHED',
#    'matchday': 38,
#    'stage': 'REGULAR_SEASON',
#    'group': None,
#    'lastUpdated': '2024-05-27T00:21:10Z',
#    'homeTeam': {'id': 559,
#     'name': 'Sevilla FC',
#     'shortName': 'Sevilla FC',
#     'tla': 'SEV',
#     'crest': 'https://crests.football-data.org/559.png'},
#    'awayTeam': {'id': 81,
#     'name': 'FC Barcelona',
#     'shortName': 'Barça',
#     'tla': 'FCB',
#     'crest': 'https://crests.football-data.org/81.png'},
#    'score': {'winner': 'AWAY_TEAM',
#     'duration': 'REGULAR',
#     'fullTime': {'home': 1, 'away': 2},
#     'halfTime': {'home': 1, 'away': 1}},
#    'odds': {'msg': 'Activate Odds-Package in User-Panel to retrieve odds.'},
#    'referees': [{'id': 215462,
#      'name': 'Javier Iglesias Villanueva',
#      'type': 'REFEREE',
#      'nationality': 'Spain'}]}]}

# %%
matches_data = [{
    'utcDate': match['utcDate'],
    'homeTeam': match['homeTeam']['name'],
    'awayTeam': match['awayTeam']['name'],
    'score_home': match['score']['fullTime']['home'],
    'score_away': match['score']['fullTime']['away'],
    'matchday': match['matchday'],
    'stage': match['stage']
} for match in data['matches']]

df = pd.DataFrame(matches_data)

# %%
import pandas as pd

# Initialize Elo ratings for each team
initial_elo = 1500
team_elo = {}

# Ensure all teams are initialized
all_teams = set(df['homeTeam']).union(set(df['awayTeam']))
for team in all_teams:
    team_elo[team] = initial_elo

# Sort matches chronologically if a date column exists
if 'date' in df.columns:
    df = df.sort_values('date')

# Function to calculate the expected score
def expected_score(rating_a, rating_b):
    return 1 / (1 + 10 ** ((rating_b - rating_a) / 400))

# Function to update Elo ratings
def update_elo(elo_a, elo_b, score_a, score_b, k=30):
    expected_a = expected_score(elo_a, elo_b)
    expected_b = expected_score(elo_b, elo_a)

    # Update the Elo ratings based on the actual score
    new_elo_a = elo_a + k * (score_a - expected_a)
    new_elo_b = elo_b + k * (score_b - expected_b)

    return new_elo_a, new_elo_b

# Store results in a list
elo_history = []

# Iterate over each match
for idx, row in df.iterrows():
    home_team = row['homeTeam']
    away_team = row['awayTeam']
    home_score = row['score_home']
    away_score = row['score_away']
    
    # Get current Elo ratings
    home_elo = team_elo.get(home_team, initial_elo)
    away_elo = team_elo.get(away_team, initial_elo)
    
    # Determine match outcome (1 for win, 0.5 for draw, 0 for loss)
    if home_score > away_score:
        home_actual = 1
        away_actual = 0
    elif home_score < away_score:
        home_actual = 0
        away_actual = 1
    else:
        home_actual = 0.5
        away_actual = 0.5
    
    # Update Elo ratings
    new_home_elo, new_away_elo = update_elo(home_elo, away_elo, home_actual, away_actual)
    
    # Store updated Elo ratings
    team_elo[home_team] = new_home_elo
    team_elo[away_team] = new_away_elo
    
    # Track Elo history for analysis or display
    elo_history.append({
        'date': row.get('date', None),  # Store date if available
        'home_team': home_team,
        'away_team': away_team,
        'home_elo_before': home_elo,
        'away_elo_before': away_elo,
        'home_elo_after': new_home_elo,
        'away_elo_after': new_away_elo,
        'home_score': home_score,
        'away_score': away_score
    })

# Convert Elo history to a DataFrame for analysis or display
elo_df = pd.DataFrame(elo_history)

# Remove matches that haven't been played (NaN scores)
elo_df = elo_df.dropna(subset=['home_score', 'away_score'])

elo_df
# Out:
#      date                home_team                 away_team  home_elo_before  \
# 0    None               UD Almería  Rayo Vallecano de Madrid      1500.000000
# 1    None               Sevilla FC               Valencia CF      1500.000000
# 2    None  Real Sociedad de Fútbol                 Girona FC      1500.000000
# 3    None            UD Las Palmas              RCD Mallorca      1500.000000
# 4    None            Athletic Club            Real Madrid CF      1500.000000
# ..    ...                      ...                       ...              ...
# 375  None           Real Madrid CF       Real Betis Balompié      1728.464390
# 376  None                Getafe CF              RCD Mallorca      1439.172352
# 377  None         RC Celta de Vigo               Valencia CF      1474.293505
# 378  None            UD Las Palmas          Deportivo Alavés      1408.949207
# 379  None               Sevilla FC              FC Barcelona      1460.335274
#
#      away_elo_before  home_elo_after  away_elo_after  home_score  away_score
# 0        1500.000000     1485.000000     1515.000000           0           2
# 1        1500.000000     1485.000000     1515.000000           1           2
# 2        1500.000000     1500.000000     1500.000000           1           1
# 3        1500.000000     1500.000000     1500.000000           1           1
# 4        1500.000000     1485.000000     1515.000000           0           2
# ..               ...             ...             ...         ...         ...
# 375      1523.924174     1720.529838     1531.858726           0           0
# 376      1448.760691     1424.586209     1463.346834           1           2
# 377      1465.535573     1473.915474     1465.913603           2           2
# 378      1495.474542     1412.609447     1491.814302           1           1
# 379      1659.520197     1453.101958     1666.753514           1           2
#
# [380 rows x 9 columns]

# %%
# Get the latest Elo ratings for each team
latest_home_elos = elo_df.groupby("home_team")["home_elo_after"].last().reset_index()
latest_away_elos = elo_df.groupby("away_team")["away_elo_after"].last().reset_index()

# Merge the two (some teams may only appear in home or away)
standings = pd.merge(latest_home_elos, latest_away_elos, 
                     left_on="home_team", right_on="away_team", 
                     how="outer")

# Fill missing values where a team may have only played home or away
standings["team"] = standings["home_team"].combine_first(standings["away_team"])
standings["home_elo"] = standings["home_elo_after"].fillna(initial_elo)
standings["away_elo"] = standings["away_elo_after"].fillna(initial_elo)

# Keep only relevant columns
standings = standings[["team", "home_elo", "away_elo"]]

# Compute the overall Elo rating (average of home and away)
standings["overall_elo"] = standings[["home_elo", "away_elo"]].mean(axis=1)

# Sort standings by highest Elo rating
standings = standings.sort_values(by="overall_elo", ascending=False).reset_index(drop=True)

# Display standings
standings[['team', 'overall_elo']]
# Out:
#                         team  overall_elo
# 0             Real Madrid CF  1724.497114
# 1               FC Barcelona  1663.136855
# 2                  Girona FC  1610.329468
# 3    Club Atlético de Madrid  1596.132133
# 4              Athletic Club  1566.747602
# 5              Villarreal CF  1553.165197
# 6    Real Sociedad de Fútbol  1542.826872
# 7        Real Betis Balompié  1527.891450
# 8           Deportivo Alavés  1493.644422
# 9           RC Celta de Vigo  1474.104490
# 10               Valencia CF  1465.724588
# 11                CA Osasuna  1461.631284
# 12                Sevilla FC  1456.718616
# 13              RCD Mallorca  1456.053762
# 14                 Getafe CF  1431.879280
# 15  Rayo Vallecano de Madrid  1428.533851
# 16                  Cádiz CF  1427.971579
# 17             UD Las Palmas  1410.779327
# 18                UD Almería  1370.290268
# 19                Granada CF  1337.941842
