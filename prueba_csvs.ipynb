# %%
import pandas as pd

df = pd.read_csv('scraping/tables/laliga_season_2017_2018', index_col=0)

# %%
df
# Out:
#                  Player     #  Nation    Pos     Age  Min  Gls  Ast  PK  \
# 0             Alexander  11.0  ar ARG     LW  28-309   90    0    0   0
# 1            Diego Rico  15.0  es ESP     LB  24-176   90    0    0   0
# 2            Erik Morán   4.0  es ESP     DM  26-085   26    0    0   0
# 3        Ezequiel Muñoz  19.0  ar ARG     CB  26-314   90    0    0   0
# 4               Gabriel   8.0  br BRA  DM,AM  23-334   90    1    0   0
# ...                 ...   ...     ...    ...     ...  ...  ...  ...  ..
# 10551        Raúl Navas  22.0  es ESP     CB  30-009   90    0    0   0
# 10552    Sergio Canales  16.0  es ESP     RW  27-093   28    0    0   0
# 10553      Willian José  12.0  br BRA     FW  26-178   90    0    0   0
# 10554       Xabi Prieto  10.0  es ESP     DM  34-264    2    0    0   0
# 10555  Álvaro Odriozola  19.0  es ESP     RB  22-157   20    0    0   0
#
#        PKatt  ...  AvgLen.1  Opp  Stp  Stp%  #OPA  AvgDist  team_id  match_id  \
# ...
